# %% [markdown]
# # Libraries
# - numpy==1.23.5
# - pandas==2.0.0
# - lightgbm==3.3.5
# - sklearn==1.2.2
# - keras==2.12.0 (no GPU support)

# %%
import os 
import numpy as np
import pandas as pd

import lightgbm as lgb

from sklearn.metrics import f1_score 
from sklearn.model_selection import KFold
from sklearn import preprocessing

import keras 
from keras.layers import *
from keras.optimizers import *
from keras.models import Model
from keras import backend as K

import warnings
warnings.filterwarnings("ignore")

# %%
DIR  = "data/"
SEED = 1881

SEED = 1109

if not os.path.isdir("models/"):
    os.makedirs("models")

# %%
train_x = pd.read_csv(DIR+"train_values.csv")
train_y = pd.read_csv(DIR+"train_labels.csv")
test_x  = pd.read_csv(DIR+"test_values.csv")
sub_csv = pd.read_csv(DIR+"submission_format.csv")

# %% [markdown]
# # 1 - Data processing

# %% [markdown]
# ## 1.1 AutoEncoder for Geo location features
# Ref: https://github.com/Goodsea/Richter-s-Eye/blob/master/main.ipynb

# %% [markdown]
# ### 1.1.1 Binary encode all geo level features

# %%
geo1 = np.array(pd.get_dummies(pd.concat([train_x["geo_level_1_id"], test_x["geo_level_1_id"]])))
geo2 = np.array(pd.get_dummies(pd.concat([train_x["geo_level_2_id"], test_x["geo_level_2_id"]])))
geo3 = np.array(pd.get_dummies(pd.concat([train_x["geo_level_3_id"], test_x["geo_level_3_id"]])))

# %% [markdown]
# ### 1.1.2 Construct Autoencoder network

# %%
def NET():
    inp = Input((geo3.shape[1],))
    i1 = Dense(16, name="intermediate")(inp)
    x2 = Dense(geo2.shape[1], activation='sigmoid')(i1)
    x1 = Dense(geo1.shape[1], activation='sigmoid')(i1)

    model = Model(inp, [x2,x1])
    model.compile(loss="binary_crossentropy", optimizer="adam")
    return model

# %% [markdown]
# Fit the model on processed geo features or Load a pretrained model

# %%
model = NET()
# Train GEO-Embed model: Uncomment the code below
# model.fit(geo3, [geo2, geo1], batch_size=128, epochs=10, verbose=2)
# model.save("geo_embed.h5")

# Load GEO-Embed pretrained Model
model.load_weights("geo_embed.h5")

# %% [markdown]
# Define function to extract the intermediate layer as the new embedding

# %%
get_int_layer_output = K.function([model.layers[0].input],
                                  [model.layers[1].output])

# %% [markdown]
# ### 1.2 Extract new embedding for geo levels and add to dataframe

# %%
# Train data
out = []
for dat in geo3[:260601]:
    layer_output = get_int_layer_output([dat.reshape(1, 11861)])[0]
    out.append(layer_output)

out = np.array(out)
out = np.squeeze(out)

train_data = pd.get_dummies(train_x.copy())
train_data = train_data.drop(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id'], axis=1)
train_data = train_data.assign(geo_feat1=out[:,0],
                               geo_feat2=out[:,1],
                               geo_feat3=out[:,2],  
                               geo_feat4=out[:,3],
                               geo_feat5=out[:,4],    
                               geo_feat6=out[:,5],
                               geo_feat7=out[:,6],
                               geo_feat8=out[:,7],
                               geo_feat9=out[:,8],
                               geo_feat10=out[:,9],
                               geo_feat11=out[:,10],
                               geo_feat12=out[:,11],
                               geo_feat13=out[:,12],
                               geo_feat14=out[:,13],
                               geo_feat15=out[:,14],           
                               geo_feat16=out[:,15])
train_data
# Out:
#         building_id  count_floors_pre_eq  age  area_percentage
# 0            802906                    2   30                6  \
# 1             28830                    2   10                8
# 2             94947                    2   10                5
# 3            590882                    2   10                6
# 4            201944                    3   30                8
# ...             ...                  ...  ...              ...
# 260596       688636                    1   55                6
# 260597       669485                    2    0                6
# 260598       602512                    3   55                6
# 260599       151409                    2   10               14
# 260600       747594                    3   10                7
#
#         height_percentage  has_superstructure_adobe_mud
# 0                       5                             1  \
# 1                       7                             0
# 2                       5                             0
# 3                       5                             0
# 4                       9                             1
# ...                   ...                           ...
# 260596                  3                             0
# 260597                  5                             0
# 260598                  7                             0
# 260599                  6                             0
# 260600                  6                             0
#
#         has_superstructure_mud_mortar_stone  has_superstructure_stone_flag
# 0                                         1                              0  \
# 1                                         1                              0
# 2                                         1                              0
# 3                                         1                              0
# 4                                         0                              0
# ...                                     ...                            ...
# 260596                                    1                              0
# 260597                                    1                              0
# 260598                                    1                              0
# 260599                                    0                              0
# 260600                                    1                              0
#
#         has_superstructure_cement_mortar_stone
# 0                                            0  \
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 260596                                       0
# 260597                                       0
# 260598                                       0
# 260599                                       0
# 260600                                       0
#
#         has_superstructure_mud_mortar_brick  ...  geo_feat7  geo_feat8
# 0                                         0  ...   1.466794  -2.044550  \
# 1                                         0  ...   0.792328  -1.930641
# 2                                         0  ...   1.379252  -2.364805
# 3                                         0  ...   1.645584  -0.355447
# 4                                         0  ...   0.998216  -2.229619
# ...                                     ...  ...        ...        ...
# 260596                                    0  ...  -0.143475  -1.791613
# 260597                                    0  ...  -0.676942  -2.418662
# 260598                                    0  ...   0.829690  -2.057462
# 260599                                    0  ...   1.648115  -1.069342
# 260600                                    0  ...  -0.057303  -0.274733
#
#         geo_feat9  geo_feat10  geo_feat11  geo_feat12  geo_feat13  geo_feat14
# 0       -1.338502    0.522944   -0.658317   -1.996131    1.364559    1.150429  \
# 1        0.244771    0.821282   -1.682540   -0.781844    1.162983   -0.517174
# 2       -1.095964   -1.032024   -1.567636   -0.170536    2.197870   -1.740250
# 3       -1.220192    1.386736   -1.921839    0.495985   -0.817264   -1.476800
# 4       -2.360607   -1.019490   -1.564085    0.837669    1.749065   -1.862957
# ...           ...         ...         ...         ...         ...         ...
# 260596  -1.062033    1.642672   -1.544195   -1.436718    0.894187   -1.064682
# 260597  -1.692341    1.550785   -0.663093   -1.541144    1.177135   -0.965449
# 260598  -1.013165    2.013322    0.062592   -1.616684    1.965572    1.093879
# 260599  -1.993976    1.468483    0.345005   -1.379133   -0.399066   -2.365860
# 260600  -0.512576    0.972008   -1.043256    0.580254    1.960608   -2.102939
#
#         geo_feat15  geo_feat16
# 0        -1.650674    1.423452
# 1        -1.422999    0.489339
# 2        -1.110470    2.265696
# 3        -0.671453    1.848267
# 4        -0.837888    1.602420
# ...            ...         ...
# 260596    0.495309    1.850656
# 260597    1.004659    0.579021
# 260598    0.540577    1.351077
# 260599    0.549455    1.766544
# 260600   -1.983914    2.729640
#
# [260601 rows x 82 columns]

# %%
# Test data
out = []
for dat in geo3[260601:]:
    layer_output = get_int_layer_output([dat.reshape(1, 11861)])[0]
    out.append(layer_output)

out = np.array(out)
out = np.squeeze(out)

test_data = pd.get_dummies(test_x.copy())
test_data = test_data.drop(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id'], axis=1)
test_data = test_data.assign(geo_feat1=out[:,0],
                             geo_feat2=out[:,1],
                             geo_feat3=out[:,2],  
                             geo_feat4=out[:,3],
                             geo_feat5=out[:,4],    
                             geo_feat6=out[:,5],
                             geo_feat7=out[:,6],
                             geo_feat8=out[:,7],
                             geo_feat9=out[:,8],
                             geo_feat10=out[:,9],
                             geo_feat11=out[:,10],
                             geo_feat12=out[:,11],
                             geo_feat13=out[:,12],
                             geo_feat14=out[:,13],
                             geo_feat15=out[:,14],           
                             geo_feat16=out[:,15])
test_data
# Out:
#        building_id  count_floors_pre_eq  age  area_percentage
# 0           300051                    3   20                7  \
# 1            99355                    2   25               13
# 2           890251                    2    5                4
# 3           745817                    1    0               19
# 4           421793                    3   15                8
# ...            ...                  ...  ...              ...
# 86863       310028                    3   70               20
# 86864       663567                    3   25                6
# 86865      1049160                    1   50                3
# 86866       442785                    2    5                9
# 86867       501372                    2   10               11
#
#        height_percentage  has_superstructure_adobe_mud
# 0                      6                             0  \
# 1                      5                             0
# 2                      5                             0
# 3                      3                             0
# 4                      7                             0
# ...                  ...                           ...
# 86863                  6                             0
# 86864                  7                             1
# 86865                  3                             0
# 86866                  5                             1
# 86867                  4                             0
#
#        has_superstructure_mud_mortar_stone  has_superstructure_stone_flag
# 0                                        1                              0  \
# 1                                        1                              0
# 2                                        1                              0
# 3                                        0                              0
# 4                                        1                              0
# ...                                    ...                            ...
# 86863                                    1                              0
# 86864                                    1                              1
# 86865                                    1                              0
# 86866                                    1                              0
# 86867                                    0                              0
#
#        has_superstructure_cement_mortar_stone
# 0                                           0  \
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 86863                                       0
# 86864                                       0
# 86865                                       0
# 86866                                       0
# 86867                                       0
#
#        has_superstructure_mud_mortar_brick  ...  geo_feat7  geo_feat8
# 0                                        0  ...  -0.430310  -1.036007  \
# 1                                        0  ...   1.198316  -1.658057
# 2                                        0  ...   0.878997  -0.098311
# 3                                        0  ...   1.829058  -1.253964
# 4                                        0  ...  -0.775551  -1.498556
# ...                                    ...  ...        ...        ...
# 86863                                    0  ...   0.815776  -1.888190
# 86864                                    0  ...   1.539498  -1.648497
# 86865                                    0  ...   1.235654  -0.985354
# 86866                                    0  ...   1.941297  -2.894349
# 86867                                    0  ...   1.561243  -1.746819
#
#        geo_feat9  geo_feat10  geo_feat11  geo_feat12  geo_feat13  geo_feat14
# 0      -0.628201    1.396918   -0.646301   -0.401721    1.775716   -0.525752  \
# 1      -0.896333    0.958980   -0.607773   -1.545761    0.012132    0.605375
# 2      -0.367600    1.122562   -1.336323   -0.563150    0.142514   -1.042175
# 3      -2.191850    1.562519    0.324142   -1.490117   -0.430267   -2.678957
# 4       0.408616    1.177538   -1.127435   -0.428089    1.805395    0.195895
# ...          ...         ...         ...         ...         ...         ...
# 86863  -2.218592    2.016480    0.878734   -1.145824    1.932422   -1.522319
# 86864  -1.291400    1.608987   -1.017836   -1.125162    1.162247    0.355431
# 86865   0.304887    1.557580   -1.386231   -0.497524    0.277491   -0.896868
# 86866   0.021195    1.277626   -2.116505   -1.672430   -0.155020    1.588272
# 86867  -1.956067    2.001912    0.163841   -2.610810    0.587409   -1.909307
#
#        geo_feat15  geo_feat16
# 0        0.589180    1.922086
# 1       -1.019763    0.474312
# 2        0.012609    1.281353
# 3        0.555670    1.977267
# 4       -0.223472    1.146803
# ...           ...         ...
# 86863   -1.862096    0.579397
# 86864    0.586007    1.033257
# 86865   -0.636278    1.854645
# 86866   -1.446333    2.817224
# 86867   -0.928045    1.487537
#
# [86868 rows x 82 columns]

# %% [markdown]
# ## 1.3 Prepare train and test data

# %%
# Train data
df = train_data.drop(["building_id"], axis=1)
x = np.array(df)

y = np.array(train_y["damage_grade"])-1

# Test data
df_test = test_data.drop(["building_id"], axis=1)
x_test = np.array(df_test)

# %% [markdown]
# # 2 - Model training

# %% [markdown]
# ## 2.1 Get labels from prediction probability
# Extract predicted labels by picking the labels that has highest probability, returning one-hot vector per prediction

# %%
def threshold_arr(array):
    # Get major confidence-scored predicted value.
    new_arr = []
    for ix, val in enumerate(array):
        loc = np.array(val).argmax(axis=0)
        k = list(np.zeros((len(val))))
        k[loc]=1
        new_arr.append(k)
        
    return np.array(new_arr)

# %% [markdown]
# ## 2.2 Train 8 LightGBM models on 8-folds setting
# All models have the same hyperparameters

# %%
kf = KFold(n_splits=8, shuffle=True, random_state=SEED)
for ix, (train_index, test_index) in enumerate(kf.split(x)):
    lgb_params = {
        "objective" : "multiclass",
        "num_class":3,
        "metric" : "auc_mu",
        "boosting": 'gbdt',
        "max_depth" : -1,
        "num_leaves" : 30,
        "learning_rate" : 0.1,
        "feature_fraction" : 0.5,
        "min_sum_hessian_in_leaf" : 0.1,
        "max_bin":8192,
        "verbosity" : 1,
        "num_threads":6,
        "seed": SEED
    }
    x_train, x_val, y_train, y_val= x[train_index], x[test_index], y[train_index], y[test_index]

    train_data_ = lgb.Dataset(x_train, label=y_train)
    val_data_   = lgb.Dataset(x_val, label=y_val)

    lgb_clf = lgb.train(lgb_params,
                        train_data_,
                        3000,
                        valid_sets = [val_data_],
                        verbose_eval = 1000)

    y_pred = lgb_clf.predict(x_val)
    print("F1-MICRO SCORE: ", f1_score(np.array(pd.get_dummies(y_val)), threshold_arr(y_pred), average='micro'))
    lgb_clf.save_model(f'models/model{ix}.txt')
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075924 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120546
# [LightGBM] [Info] Number of data points in the train set: 228025, number of used features: 80
# [LightGBM] [Info] Start training from score -2.344522
# [LightGBM] [Info] Start training from score -0.563314
# [LightGBM] [Info] Start training from score -1.094258
# [1000]	valid_0's auc_mu: 0.921772
# [2000]	valid_0's auc_mu: 0.922028
# [3000]	valid_0's auc_mu: 0.921103
# F1-MICRO SCORE:  0.747759086444008
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120800
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 80
# [LightGBM] [Info] Start training from score -2.338917
# [LightGBM] [Info] Start training from score -0.564737
# [LightGBM] [Info] Start training from score -1.093451
# [1000]	valid_0's auc_mu: 0.92075
# [2000]	valid_0's auc_mu: 0.921578
# [3000]	valid_0's auc_mu: 0.920848
# F1-MICRO SCORE:  0.7510053722179586
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046093 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120841
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 80
# [LightGBM] [Info] Start training from score -2.341969
# [LightGBM] [Info] Start training from score -0.563696
# [LightGBM] [Info] Start training from score -1.094341
# [1000]	valid_0's auc_mu: 0.922309
# [2000]	valid_0's auc_mu: 0.922864
# [3000]	valid_0's auc_mu: 0.922204
# F1-MICRO SCORE:  0.7518956254796623
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120769
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 81
# [LightGBM] [Info] Start training from score -2.337236
# [LightGBM] [Info] Start training from score -0.563619
# [LightGBM] [Info] Start training from score -1.095836
# [1000]	valid_0's auc_mu: 0.921068
# [2000]	valid_0's auc_mu: 0.921527
# [3000]	valid_0's auc_mu: 0.920879
# F1-MICRO SCORE:  0.7478434382194934
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120679
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 80
# [LightGBM] [Info] Start training from score -2.338781
# [LightGBM] [Info] Start training from score -0.563257
# [LightGBM] [Info] Start training from score -1.096006
# [1000]	valid_0's auc_mu: 0.923367
# [2000]	valid_0's auc_mu: 0.924145
# [3000]	valid_0's auc_mu: 0.9234
# F1-MICRO SCORE:  0.7541980046047582
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120913
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 81
# [LightGBM] [Info] Start training from score -2.336691
# [LightGBM] [Info] Start training from score -0.564274
# [LightGBM] [Info] Start training from score -1.094878
# [1000]	valid_0's auc_mu: 0.922446
# [2000]	valid_0's auc_mu: 0.922953
# [3000]	valid_0's auc_mu: 0.922076
# F1-MICRO SCORE:  0.7503607060629317
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038541 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120744
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 80
# [LightGBM] [Info] Start training from score -2.341604
# [LightGBM] [Info] Start training from score -0.564182
# [LightGBM] [Info] Start training from score -1.093621
# [1000]	valid_0's auc_mu: 0.922682
# [2000]	valid_0's auc_mu: 0.923173
# [3000]	valid_0's auc_mu: 0.922345
# F1-MICRO SCORE:  0.7518035303146585
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040349 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120742
# [LightGBM] [Info] Number of data points in the train set: 228026, number of used features: 81
# [LightGBM] [Info] Start training from score -2.333656
# [LightGBM] [Info] Start training from score -0.565161
# [LightGBM] [Info] Start training from score -1.094250
# [1000]	valid_0's auc_mu: 0.923451
# [2000]	valid_0's auc_mu: 0.924317
# [3000]	valid_0's auc_mu: 0.923525
# F1-MICRO SCORE:  0.7519570222563315

# %%
# Append all models to a list
models = []
for i in range(8):
    model = lgb.Booster(model_file=f'models/model{i}.txt')

    y_pred = model.predict(x)
    score  = f1_score(np.array(pd.get_dummies(y)), threshold_arr(y_pred), average='micro')
    print("F1-MICRO SCORE: ", score)
    models.append(model)
# Out:
# F1-MICRO SCORE:  0.8427749701651185
# F1-MICRO SCORE:  0.8425332212846459
# F1-MICRO SCORE:  0.8421034454971393
# F1-MICRO SCORE:  0.8423106588232585
# F1-MICRO SCORE:  0.8429322988016161
# F1-MICRO SCORE:  0.8429591597883355
# F1-MICRO SCORE:  0.8426176415286204
# F1-MICRO SCORE:  0.8420804217942371

# %% [markdown]
# ## 2.3 Model ensembling
# We simply take the sum over probability predictions of all models, and again, pick the labels that has maximum accumulated probability

# %%
def ensemble(models, x):
    y_preds = []
    
    for model in models:
        y_pred = model.predict(x)
        y_preds.append(y_pred)
        
    init_y_pred = y_preds[0]
    for ypred in y_preds[1:]:
        init_y_pred += ypred
        
    y_pred = threshold_arr(init_y_pred)
    
    return y_pred

# %%
y_pred = ensemble(models, x_test)
y_pred = y_pred.argmax(axis=1)+1

# %% [markdown]
# ## 2.4 Generate prediction file

# %%
sub_csv["damage_grade"] = y_pred
sub_csv.to_csv("submission.csv", index=False)
